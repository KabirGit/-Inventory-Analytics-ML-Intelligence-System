# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import sqlite3
from scipy.stats import ttest_ind
import scipy.stats as stats
warnings.filterwarnings('ignore')

# %% [raw]
# # loading the dataset

# %%
#creating db connection bro
conn=sqlite3.connect('inventory.db')

#fetching the data bro
df=pd.read_sql_query('select * from vendor_sales_summary',conn)
df.head()
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    ActualPrice  Volume  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0        36.99  1750.0                 145080            3811251.60
# 1        28.99  1750.0                 164038            3804041.22
# 2        24.99  1750.0                 187407            3418303.68
# 3        22.99  1750.0                 201682            3261197.94
# 4        29.99  1750.0                 138109            3023206.01
#
#    TotalSalesQuantity  TotalSalesDollars  TotalSalesPrice  TotalExciseTax  \
# 0            142049.0       5.101920e+06        672819.31       260999.20
# 1            160247.0       4.819073e+06        561512.37       294438.66
# 2            187140.0       4.538121e+06        461140.15       343854.07
# 3            200412.0       4.475973e+06        420050.01       368242.80
# 4            135838.0       4.223108e+06        545778.28       249587.83
#
#    FreightCost  GrossProfit  ProfitMargin  StockTurnover  SalesToPurchaseRatio
# 0     68601.68   1290667.91     25.297693       0.979108              1.338647
# 1    144929.24   1015032.27     21.062810       0.976890              1.266830
# 2    123780.22   1119816.92     24.675786       0.998575              1.327594
# 3    257032.07   1214774.94     27.139908       0.993703              1.372493
# 4    257032.07   1199901.61     28.412764       0.983556              1.396897

# %% [markdown]
# # EDA
# WE ANALYZE THE RESULTANT TABLE TO GAIN INSIGHTS INTO DISTRIBUTION OF EACH COLUMN AND METRIC
#     helps us understand
#     -data patterns
#     -identify anomalies
#     -data quality
#     for further analysis

# %%
#summary statistics
df.transpose()
# Out:
#                                          0                      1      \
# VendorNumber                              1128                   4425
# VendorName                   BROWN-FORMAN CORP  MARTIGNETTI COMPANIES
# Brand                                     1233                   3405
# Description            Jack Daniels No 7 Black  Tito's Handmade Vodka
# ActualPrice                              36.99                  28.99
# Volume                                  1750.0                 1750.0
# TotalPurchaseQuantity                   145080                 164038
# TotalPurchaseDollars                 3811251.6             3804041.22
# TotalSalesQuantity                    142049.0               160247.0
# TotalSalesDollars               5101919.510001             4819073.49
# TotalSalesPrice                      672819.31              561512.37
# TotalExciseTax                        260999.2              294438.66
# FreightCost                           68601.68              144929.24
# GrossProfit                         1290667.91             1015032.27
# ProfitMargin                         25.297693               21.06281
# StockTurnover                         0.979108                0.97689
# SalesToPurchaseRatio                  1.338647                1.26683
#
#                                    2                         3      \
# VendorNumber                       17035                      3960
# VendorName             PERNOD RICARD USA  DIAGEO NORTH AMERICA INC
# Brand                               8068                      4261
# Description             Absolut 80 Proof    Capt Morgan Spiced Rum
# ActualPrice                        24.99                     22.99
# Volume                            1750.0                    1750.0
# TotalPurchaseQuantity             187407                    201682
# TotalPurchaseDollars          3418303.68                3261197.94
# TotalSalesQuantity              187140.0                  200412.0
# TotalSalesDollars              4538120.6                4475972.88
# TotalSalesPrice                461140.15                 420050.01
# TotalExciseTax                 343854.07                  368242.8
# FreightCost                    123780.22                 257032.07
# GrossProfit                   1119816.92                1214774.94
# ProfitMargin                   24.675786                 27.139908
# StockTurnover                   0.998575                  0.993703
# SalesToPurchaseRatio            1.327594                  1.372493
#
#                                           4                 5      \
# VendorNumber                               3960               480
# VendorName             DIAGEO NORTH AMERICA INC   BACARDI USA INC
# Brand                                      3545              3858
# Description                     Ketel One Vodka  Grey Goose Vodka
# ActualPrice                               29.99             23.99
# Volume                                   1750.0             750.0
# TotalPurchaseQuantity                    138109            138809
# TotalPurchaseDollars                 3023206.01        2466635.93
# TotalSalesQuantity                     135838.0          141860.0
# TotalSalesDollars                    4223107.62    3383912.400001
# TotalSalesPrice                       545778.28         446932.09
# TotalExciseTax                        249587.83         111699.19
# FreightCost                           257032.07          89286.27
# GrossProfit                          1199901.61         917276.47
# ProfitMargin                          28.412764          27.10698
# StockTurnover                          0.983556           1.02198
# SalesToPurchaseRatio                   1.396897          1.371873
#
#                                        6                         7      \
# VendorNumber                           17035                      3960
# VendorName                 PERNOD RICARD USA  DIAGEO NORTH AMERICA INC
# Brand                                   2589                      3102
# Description            Jameson Irish Whiskey         Smirnoff Traveler
# ActualPrice                            39.99                     17.99
# Volume                                1750.0                    1750.0
# TotalPurchaseQuantity                  70783                    161386
# TotalPurchaseDollars              2177285.08                2088334.84
# TotalSalesQuantity                   69627.0                  148265.0
# TotalSalesDollars                 2773367.73                2592041.35
# TotalSalesPrice                    614529.34                 292586.29
# TotalExciseTax                     127931.67                  272422.6
# FreightCost                        123780.22                 257032.07
# GrossProfit                        596082.65                 503706.51
# ProfitMargin                       21.493098                 19.432812
# StockTurnover                       0.983668                  0.918698
# SalesToPurchaseRatio                1.273773                    1.2412
#
#                                           8                        9      ...  \
# VendorNumber                               3960                    12546  ...
# VendorName             DIAGEO NORTH AMERICA INC  JIM BEAM BRANDS COMPANY  ...
# Brand                                      3489                     1376  ...
# Description                           Tanqueray                 Jim Beam  ...
# ActualPrice                               27.99                    21.99  ...
# Volume                                   1750.0                   1750.0  ...
# TotalPurchaseQuantity                     91835                   108866  ...
# TotalPurchaseDollars                 1903739.55               1773427.14  ...
# TotalSalesQuantity                      90481.0                 107061.0  ...
# TotalSalesDollars                    2640491.19               2435393.39  ...
# TotalSalesPrice                       503661.02                426902.78  ...
# TotalExciseTax                        166244.44                196707.35  ...
# FreightCost                           257032.07                123880.97  ...
# GrossProfit                           736751.64                661966.25  ...
# ProfitMargin                          27.902068                27.181081  ...
# StockTurnover                          0.985256                  0.98342  ...
# SalesToPurchaseRatio                   1.387002                 1.373269  ...
#
#                                              10682  \
# VendorNumber                                  4425
# VendorName                   MARTIGNETTI COMPANIES
# Brand                                        27934
# Description            Terruzzi & Puthod Vernaccia
# ActualPrice                                   4.99
# Volume                                       750.0
# TotalPurchaseQuantity                            1
# TotalPurchaseDollars                          3.37
# TotalSalesQuantity                             1.0
# TotalSalesDollars                             4.99
# TotalSalesPrice                               4.99
# TotalExciseTax                                0.11
# FreightCost                              144929.24
# GrossProfit                                   1.62
# ProfitMargin                              32.46493
# StockTurnover                                  1.0
# SalesToPurchaseRatio                      1.480712
#
#                                             10683                     10684  \
# VendorNumber                                 6785                     90024
# VendorName             PALM BAY INTERNATIONAL INC            VINILANDIA USA
# Brand                                       22161                     46135
# Description            Santa Rita Organic Svgn Bl  Aresti Pnt Nr Curico Vly
# ActualPrice                                  4.99                     10.99
# Volume                                      750.0                     750.0
# TotalPurchaseQuantity                           1                         1
# TotalPurchaseDollars                         3.35                      3.28
# TotalSalesQuantity                            1.0                      19.0
# TotalSalesDollars                            9.99                     94.81
# TotalSalesPrice                              9.99                     59.88
# TotalExciseTax                               0.11                      2.12
# FreightCost                              13605.41                   2802.64
# GrossProfit                                  6.64                     91.53
# ProfitMargin                            66.466466                 96.540449
# StockTurnover                                 1.0                      19.0
# SalesToPurchaseRatio                      2.98209                 28.905488
#
#                                            10685                     10686  \
# VendorNumber                                3960                      3960
# VendorName              DIAGEO NORTH AMERICA INC  DIAGEO NORTH AMERICA INC
# Brand                                       8729                      2626
# Description            Smirnoff Light Strawberry         Crown Royal Apple
# ActualPrice                                 0.99                      1.99
# Volume                                      50.0                      50.0
# TotalPurchaseQuantity                          4                         2
# TotalPurchaseDollars                        2.96                      2.84
# TotalSalesQuantity                           6.0                      14.0
# TotalSalesDollars                           5.94                     27.86
# TotalSalesPrice                             2.97                      5.97
# TotalExciseTax                              0.31                      0.73
# FreightCost                            257032.07                 257032.07
# GrossProfit                                 2.98                     25.02
# ProfitMargin                            50.16835                 89.806174
# StockTurnover                                1.5                       7.0
# SalesToPurchaseRatio                    2.006757                  9.809859
#
#                                              10687  \
# VendorNumber                                  9815
# VendorName                          WINE GROUP INC
# Brand                                         8527
# Description            Concannon Glen Ellen Wh Zin
# ActualPrice                                   4.99
# Volume                                       750.0
# TotalPurchaseQuantity                            2
# TotalPurchaseDollars                          2.64
# TotalSalesQuantity                             5.0
# TotalSalesDollars                            15.95
# TotalSalesPrice                              10.96
# TotalExciseTax                                0.55
# FreightCost                               27100.41
# GrossProfit                                  13.31
# ProfitMargin                             83.448276
# StockTurnover                                  2.5
# SalesToPurchaseRatio                      6.041667
#
#                                              10688                     10689  \
# VendorNumber                                  8004                      3924
# VendorName                          SAZERAC CO INC  HEAVEN HILL DISTILLERIES
# Brand                                         5683                      9123
# Description            Dr McGillicuddy's Apple Pie           Deep Eddy Vodka
# ActualPrice                                   0.49                      0.99
# Volume                                        50.0                      50.0
# TotalPurchaseQuantity                            6                         2
# TotalPurchaseDollars                          2.34                      1.48
# TotalSalesQuantity                           134.0                       2.0
# TotalSalesDollars                            65.66                      1.98
# TotalSalesPrice                               1.47                      0.99
# TotalExciseTax                                7.04                       0.1
# FreightCost                               50293.62                  14069.87
# GrossProfit                                  63.32                       0.5
# ProfitMargin                             96.436186                 25.252525
# StockTurnover                            22.333333                       1.0
# SalesToPurchaseRatio                     28.059829                  1.337838
#
#                                              10690                     10691
# VendorNumber                                  3960                      7245
# VendorName                DIAGEO NORTH AMERICA INC      PROXIMO SPIRITS INC.
# Brand                                         6127                      3065
# Description            The Club Strawbry Margarita  Three Olives Grape Vodka
# ActualPrice                                   1.99                      0.99
# Volume                                       200.0                      50.0
# TotalPurchaseQuantity                            1                         1
# TotalPurchaseDollars                          1.47                      0.71
# TotalSalesQuantity                            72.0                      86.0
# TotalSalesDollars                           143.28                     85.14
# TotalSalesPrice                              77.61                     33.66
# TotalExciseTax                               15.12                      4.46
# FreightCost                              257032.07                  38994.78
# GrossProfit                                 141.81                     84.43
# ProfitMargin                             98.974037                 99.166079
# StockTurnover                                 72.0                      86.0
# SalesToPurchaseRatio                     97.469388                119.915493
#
# [17 rows x 10692 columns]
